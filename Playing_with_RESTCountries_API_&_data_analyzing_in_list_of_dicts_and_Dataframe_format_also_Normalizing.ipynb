# %% [markdown]
# <a href="https://colab.research.google.com/github/SunnyChaturvedi/2Pass-Assembler-and-Emulator/blob/main/Playing_with_RESTCountries_API_%26_data_analyzing_in_list_of_dicts_and_Dataframe_format_also_Normalizing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd
import datetime

# %%
# Get the current date
today = datetime.date.today().strftime('%d-%m-%Y')

# Set the API endpoint and parameters
url = "https://restcountries.com/v3.1/independent"

# Send a GET request to the API endpoint
response = requests.get(url)

# %%
# prompt: how to check type of response object
print(type(response))
print(type(response.json()))
# Out:
# <class 'requests.models.Response'>
# <class 'list'>

# %%
df = pd.DataFrame(response.json())
df.head(1)
# Out:
#                                                 name    tld cca2 ccn3 cca3  \
# 0  {'common': 'Cyprus', 'official': 'Republic of ...  [.cy]   CY  196  CYP
#
#   cioc  independent               status  unMember  \
# 0  CYP         True  officially-assigned      True
#
#                                  currencies  ... fifa  \
# 0  {'EUR': {'name': 'Euro', 'symbol': '€'}}  ...  CYP
#
#                                  car    timezones continents  \
# 0  {'signs': ['CY'], 'side': 'left'}  [UTC+02:00]   [Europe]
#
#                                                flags  \
# 0  {'png': 'https://flagcdn.com/w320/cy.png', 'sv...
#
#                                           coatOfArms startOfWeek  \
# 0  {'png': 'https://mainfacts.com/media/images/co...      monday
#
#                   capitalInfo                                postalCode  \
# 0  {'latlng': [35.17, 33.37]}  {'format': '####', 'regex': '^(\d{4})$'}
#
#    borders
# 0      NaN
#
# [1 rows x 35 columns]

# %%
# prompt: drop tld, cca2, ccn3, cca3, cioc columns and display 1 member of head()

df.drop(columns=['tld', 'cca2', 'ccn3', 'cca3', 'cioc'], inplace=True)
df.head(1)
# Out:
#                                                 name  independent  \
# 0  {'common': 'Cyprus', 'official': 'Republic of ...         True
#
#                 status  unMember                                currencies  \
# 0  officially-assigned      True  {'EUR': {'name': 'Euro', 'symbol': '€'}}
#
#                                   idd    capital  \
# 0  {'root': '+3', 'suffixes': ['57']}  [Nicosia]
#
#                                         altSpellings  region        subregion  \
# 0  [CY, Kýpros, Kıbrıs, Republic of Cyprus, Κυπρι...  Europe  Southern Europe
#
#    ... fifa                                car    timezones  continents  \
# 0  ...  CYP  {'signs': ['CY'], 'side': 'left'}  [UTC+02:00]    [Europe]
#
#                                                flags  \
# 0  {'png': 'https://flagcdn.com/w320/cy.png', 'sv...
#
#                                           coatOfArms startOfWeek  \
# 0  {'png': 'https://mainfacts.com/media/images/co...      monday
#
# ...

# %%
# prompt: drop all columns except name, unMember and Capital and languages

df.drop(columns=df.columns.difference(['name', 'unMember', 'capital']), inplace=True)
df.head(1)
# Out:
#                                                 name  unMember    capital
# 0  {'common': 'Cyprus', 'official': 'Republic of ...      True  [Nicosia]

# %%
# prompt: convert this dataframe to list of dictionaries
print(df)
df_dict = df.to_dict('records')
print(df_dict)
# Out:
#                                                   name  unMember  \
# 0    {'common': 'Cyprus', 'official': 'Republic of ...      True
# 1    {'common': 'Eritrea', 'official': 'State of Er...      True
# 2    {'common': 'Liberia', 'official': 'Republic of...      True
# 3    {'common': 'Vatican City', 'official': 'Vatica...      True
# 4    {'common': 'Somalia', 'official': 'Federal Rep...      True
# ..                                                 ...       ...
# 189  {'common': 'Tunisia', 'official': 'Tunisian Re...      True
# 190  {'common': 'South Sudan', 'official': 'Republi...      True
# 191  {'common': 'Honduras', 'official': 'Republic o...      True
# 192  {'common': 'Saint Vincent and the Grenadines',...      True
# 193  {'common': 'Sri Lanka', 'official': 'Democrati...      True
#
#                          capital
# 0                      [Nicosia]
# 1                       [Asmara]
# 2                     [Monrovia]
# 3                 [Vatican City]
# ...

# %%
# prompt: normalize the result dict to a df called df2 and print it

# Normalize the result dict to a DataFrame
df2 = pd.json_normalize(df_dict)

# Print the DataFrame
print(df2.columns)
print(df2.head())
# Out:
# Index(['unMember', 'capital', 'name.common', 'name.official',
#        'name.nativeName.ell.official', 'name.nativeName.ell.common',
#        'name.nativeName.tur.official', 'name.nativeName.tur.common',
#        'name.nativeName.ara.official', 'name.nativeName.ara.common',
#        ...
#        'name.nativeName.ind.official', 'name.nativeName.ind.common',
#        'name.nativeName.nau.official', 'name.nativeName.nau.common',
#        'name.nativeName.kin.official', 'name.nativeName.kin.common',
#        'name.nativeName.mkd.official', 'name.nativeName.mkd.common',
#        'name.nativeName.sin.official', 'name.nativeName.sin.common'],
#       dtype='object', length=282)
#    unMember         capital   name.common                name.official  \
# 0      True       [Nicosia]        Cyprus           Republic of Cyprus
# 1      True        [Asmara]       Eritrea             State of Eritrea
# 2      True      [Monrovia]       Liberia          Republic of Liberia
# ...
